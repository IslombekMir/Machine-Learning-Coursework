# %% [markdown]
# ### This is a test notebook

# %%
import pandas as pd

# %%
basics = pd.read_csv('./data/title.basics.tsv', sep='\t')

# %%
basics = basics[basics['titleType'] == 'movie']

# %%
basics['startYear'].dropna()
# Out:
# 8           1894
# 144         1897
# 331         1900
# 498         1905
# 570         1906
#             ...
# 12101360    2015
# 12101384    2007
# 12101396    2013
# 12101406    2017
# 12101416    2013
# Name: startYear, Length: 732928, dtype: object

# %%
basics = basics[basics['startYear'] != '\\N']

# %%
basics = basics[pd.to_numeric(basics['startYear']) > 2015]

# %%
# Out:
# np.int64(2)
